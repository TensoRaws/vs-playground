# %%
# !nvidia-smi
# Out:
# Sat Aug  3 14:24:20 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 556.12                 Driver Version: 556.12         CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P5             18W /  165W |    2431MiB /  16380MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3368    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A      4684    C+G   ...s\Toolbox\bin\jetbrains-toolbox.exe      N/A      |
# |    0   N/A  N/A      5076    C+G   ... Synapse 3 Host\Razer Synapse 3.exe      N/A      |
# |    0   N/A  N/A      8932    C+G   C:\Program Files\ToDesk\ToDesk.exe          N/A      |
# |    0   N/A  N/A      8976    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A      9236    C+G   ...on\wallpaper_engine\wallpaper64.exe      N/A      |
# |    0   N/A  N/A     10192    C+G   D:\HoYoPlay\1.0.5.88\HYPHelper.exe          N/A      |
# |    0   N/A  N/A     11004    C+G   ...ces\Razer Central\Razer Central.exe      N/A      |
# |    0   N/A  N/A     11208    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     15236    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     16428    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     16500    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     17688    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     18924    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     20580    C+G   ...tral\CefSharp.BrowserSubprocess.exe      N/A      |
# |    0   N/A  N/A     24080    C+G   ...1.0_x64__8wekyb3d8bbwe\Video.UI.exe      N/A      |
# |    0   N/A  N/A     28464    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     29136    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     30172    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     31496    C+G   C:\Windows\System32\dwm.exe                 N/A      |
# |    0   N/A  N/A     31644    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     32092    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A     33932    C+G   ...\docker\frontend\Docker Desktop.exe      N/A      |
# |    0   N/A  N/A     41520    C+G   C:\Program Files\Tencent\QQNT\QQ.exe        N/A      |
# |    0   N/A  N/A     58256    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !conda install python=3.10.* -y
# !apt update && apt install -y libgl1-mesa-glx

# install vapoursynth
# !conda install conda-forge::vapoursynth=69 -y

# install vapoursynth C++ plugins
# !conda install -n base libarchive -c main --force-reinstall -y
# !conda install tongyuantongyu::vapoursynth-bestsource=5 -y
# !conda install tongyuantongyu::vapoursynth-fmtconv=30 -y

# install vapoursynth python plugins
# !conda install tongyuantongyu::vapoursynth-mvsfunc=10.10 -y
# !conda install tongyuantongyu::vapoursynth-vsutil=0.8.0 -y
# !pip install git+https://github.com/HomeOfVapourSynthEvolution/havsfunc.git

# install python packages
# !pip install numpy==1.26.4
# !pip install opencv-python==4.10.0.82

# install PyTorch
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# install AI packages
# !pip install vsrealesrgan
# !python -m vsrealesrgan
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-anon-usage-0.4.4  |py310hfc23b7f_100          26 KB
#     anyio-4.2.0                |  py310haa95532_0         191 KB
#     archspec-0.2.3             |     pyhd3eb1b0_0          47 KB
#     argon2-cffi-bindings-21.2.0|  py310h2bbff1b_0          36 KB
#     async-lru-2.0.4            |  py310haa95532_0          19 KB
#     attrs-23.1.0               |  py310haa95532_0         144 KB
#     babel-2.11.0               |  py310haa95532_0         6.8 MB
#     beautifulsoup4-4.12.3      |  py310haa95532_0         217 KB
#     boltons-23.0.0             |  py310haa95532_0         425 KB
#     brotli-python-1.0.9        |  py310hd77b12b_8         346 KB
#     certifi-2024.7.4           |  py310haa95532_0         159 KB
#     cffi-1.16.0                |  py310h2bbff1b_1         249 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     colorama-0.4.6             |  py310haa95532_0          32 KB
#     comm-0.2.1                 |  py310haa95532_0          15 KB
#     conda-24.7.1               |  py310haa95532_0         973 KB
#     conda-content-trust-0.2.0  |  py310haa95532_1          82 KB
#     conda-libmamba-solver-24.1.0|     pyhd3eb1b0_0          39 KB
#     conda-package-handling-2.3.0|  py310haa95532_0         295 KB
#     conda-package-streaming-0.10.0|  py310haa95532_0          29 KB
#     cryptography-42.0.5        |  py310h89fc84f_1         1.2 MB
#     debugpy-1.6.7              |  py310hd77b12b_0         2.9 MB
#     distro-1.9.0               |  py310haa95532_0          57 KB
#     exceptiongroup-1.2.0       |  py310haa95532_0          31 KB
#     frozendict-2.4.2           |  py310h2bbff1b_0          53 KB
#     idna-3.7                   |  py310haa95532_0         132 KB
#     ipykernel-6.28.0           |  py310haa95532_0         199 KB
#     ipython-8.25.0             |  py310haa95532_0         1.2 MB
#     ipywidgets-8.1.2           |  py310haa95532_0         199 KB
#     jedi-0.19.1                |  py310haa95532_0         1.0 MB
#     jinja2-3.1.4               |  py310haa95532_0         275 KB
#     jsonpatch-1.33             |  py310haa95532_1          57 KB
#     jsonpointer-2.1            |     pyhd3eb1b0_0           9 KB
#     jsonschema-4.19.2          |  py310haa95532_0         166 KB
#     jsonschema-specifications-2023.7.1|  py310haa95532_0          16 KB
#     jupyter-1.0.0              |  py310haa95532_9           8 KB
#     jupyter-lsp-2.2.0          |  py310haa95532_0          87 KB
#     jupyter_client-8.6.0       |  py310haa95532_0         204 KB
#     jupyter_console-6.6.3      |  py310haa95532_0          64 KB
#     jupyter_core-5.7.2         |  py310haa95532_0         110 KB
#     jupyter_events-0.10.0      |  py310haa95532_0          61 KB
#     jupyter_server-2.14.1      |  py310haa95532_0         527 KB
#     jupyter_server_terminals-0.4.4|  py310haa95532_1          26 KB
#     jupyterlab-4.0.11          |  py310haa95532_0         4.5 MB
#     jupyterlab_server-2.25.1   |  py310haa95532_0          88 KB
#     jupyterlab_widgets-3.0.10  |  py310haa95532_0         196 KB
#     libmambapy-1.5.8           |  py310h77c03ed_2         484 KB
#     markupsafe-2.1.3           |  py310h2bbff1b_0          25 KB
#     matplotlib-inline-0.1.6    |  py310haa95532_0          17 KB
#     menuinst-2.1.1             |  py310h5da7b33_0         196 KB
#     mistune-2.0.4              |  py310haa95532_0          94 KB
#     nbclient-0.8.0             |  py310haa95532_0         116 KB
#     nbconvert-7.10.0           |  py310haa95532_0         492 KB
#     nbformat-5.9.2             |  py310haa95532_0         156 KB
#     nest-asyncio-1.6.0         |  py310haa95532_0          15 KB
#     notebook-7.0.8             |  py310haa95532_2         3.2 MB
#     notebook-shim-0.2.3        |  py310haa95532_0          23 KB
#     overrides-7.4.0            |  py310haa95532_0          30 KB
#     packaging-24.1             |  py310haa95532_0         148 KB
#     pip-24.0                   |  py310haa95532_0         2.9 MB
#     platformdirs-3.10.0        |  py310haa95532_0          36 KB
#     pluggy-1.0.0               |  py310haa95532_1          29 KB
#     ply-3.11                   |  py310haa95532_0          81 KB
#     prometheus_client-0.14.1   |  py310haa95532_0          90 KB
#     prompt-toolkit-3.0.43      |  py310haa95532_0         592 KB
#     psutil-5.9.0               |  py310h2bbff1b_0         353 KB
#     pycosat-0.6.6              |  py310h2bbff1b_1          92 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pygments-2.15.1            |  py310haa95532_1         1.7 MB
#     pyqt-5.15.10               |  py310hd77b12b_0         4.1 MB
#     pyqt5-sip-12.13.0          |  py310h2bbff1b_0          75 KB
#     pysocks-1.7.1              |  py310haa95532_0          28 KB
#     python-3.10.14             |       he1021f5_1        15.9 MB
#     python-dateutil-2.9.0post0 |  py310haa95532_2         281 KB
#     python-fastjsonschema-2.16.2|  py310haa95532_0         232 KB
#     python-json-logger-2.0.7   |  py310haa95532_0          16 KB
#     pytz-2024.1                |  py310haa95532_0         215 KB
#     pywin32-305                |  py310h2bbff1b_0        10.7 MB
#     pywinpty-2.0.10            |  py310h5da7b33_0         226 KB
#     pyyaml-6.0.1               |  py310h2bbff1b_0         155 KB
#     pyzmq-25.1.2               |  py310hd77b12b_0         412 KB
#     qtconsole-5.5.1            |  py310haa95532_0         211 KB
#     qtpy-2.4.1                 |  py310haa95532_0         127 KB
#     referencing-0.30.2         |  py310haa95532_0          63 KB
#     requests-2.32.3            |  py310haa95532_0         101 KB
#     rfc3339-validator-0.1.4    |  py310haa95532_0          10 KB
#     rfc3986-validator-0.1.1    |  py310haa95532_0          10 KB
#     rpds-py-0.10.6             |  py310h062c2fa_0         202 KB
#     ruamel.yaml-0.17.21        |  py310h2bbff1b_0         177 KB
#     ruamel.yaml.clib-0.2.6     |  py310h2bbff1b_1         101 KB
#     send2trash-1.8.2           |  py310haa95532_0          76 KB
#     setuptools-69.5.1          |  py310haa95532_0        1013 KB
#     sip-6.7.12                 |  py310hd77b12b_0         521 KB
#     sniffio-1.3.0              |  py310haa95532_0          17 KB
#     soupsieve-2.5              |  py310haa95532_0          71 KB
#     terminado-0.17.1           |  py310haa95532_0          33 KB
#     tinycss2-1.2.1             |  py310haa95532_0          40 KB
#     tomli-2.0.1                |  py310haa95532_0          25 KB
#     tornado-6.4.1              |  py310h827c3e9_0         668 KB
#     tqdm-4.66.4                |  py310h9909e9c_0         162 KB
#     traitlets-5.14.3           |  py310haa95532_0         182 KB
#     truststore-0.8.0           |  py310haa95532_0          39 KB
#     typing-extensions-4.11.0   |  py310haa95532_0          10 KB
#     typing_extensions-4.11.0   |  py310haa95532_0          62 KB
#     urllib3-2.2.2              |  py310haa95532_0         180 KB
#     webencodings-0.5.1         |  py310haa95532_1          21 KB
#     websocket-client-1.8.0     |  py310haa95532_0         118 KB
#     wheel-0.43.0               |  py310haa95532_0         136 KB
#     widgetsnbextension-4.0.10  |  py310haa95532_0         949 KB
#     win_inet_pton-1.1.0        |  py310haa95532_0           9 KB
#     zstandard-0.22.0           |  py310h3469f8a_0         343 KB
#     ------------------------------------------------------------
#                                            Total:        72.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   exceptiongroup     pkgs/main/win-64::exceptiongroup-1.2.0-py310haa95532_0
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py310h2bbff1b_1
#   tomli              pkgs/main/win-64::tomli-2.0.1-py310haa95532_0
#
# The following packages will be UPDATED:
#
#   packaging                            23.2-py312haa95532_0 --> 24.1-py310haa95532_0
#   requests                           2.32.2-py312haa95532_0 --> 2.32.3-py310haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda-anon-usa~                0.4.4-py312hfc23b7f_100 --> 0.4.4-py310hfc23b7f_100
#   anyio                               4.2.0-py312haa95532_0 --> 4.2.0-py310haa95532_0
#   argon2-cffi-bindi~                 21.2.0-py312h2bbff1b_0 --> 21.2.0-py310h2bbff1b_0
#   async-lru                           2.0.4-py312haa95532_0 --> 2.0.4-py310haa95532_0
#   attrs                              23.1.0-py312haa95532_0 --> 23.1.0-py310haa95532_0
#   babel                              2.11.0-py312haa95532_0 --> 2.11.0-py310haa95532_0
#   beautifulsoup4                     4.12.3-py312haa95532_0 --> 4.12.3-py310haa95532_0
#   boltons                            23.0.0-py312haa95532_0 --> 23.0.0-py310haa95532_0
#   brotli-python                       1.0.9-py312hd77b12b_8 --> 1.0.9-py310hd77b12b_8
#   certifi                          2024.7.4-py312haa95532_0 --> 2024.7.4-py310haa95532_0
#   cffi                               1.16.0-py312h2bbff1b_1 --> 1.16.0-py310h2bbff1b_1
#   colorama                            0.4.6-py312haa95532_0 --> 0.4.6-py310haa95532_0
#   comm                                0.2.1-py312haa95532_0 --> 0.2.1-py310haa95532_0
#   conda                              24.7.1-py312haa95532_0 --> 24.7.1-py310haa95532_0
#   conda-content-tru~                  0.2.0-py312haa95532_1 --> 0.2.0-py310haa95532_1
#   conda-package-han~                  2.3.0-py312haa95532_0 --> 2.3.0-py310haa95532_0
#   conda-package-str~                 0.10.0-py312haa95532_0 --> 0.10.0-py310haa95532_0
#   cryptography                       42.0.5-py312h89fc84f_1 --> 42.0.5-py310h89fc84f_1
#   debugpy                             1.6.7-py312hd77b12b_0 --> 1.6.7-py310hd77b12b_0
#   distro                              1.9.0-py312haa95532_0 --> 1.9.0-py310haa95532_0
#   frozendict                          2.4.2-py312haa95532_0 --> 2.4.2-py310h2bbff1b_0
#   idna                                  3.7-py312haa95532_0 --> 3.7-py310haa95532_0
#   ipykernel                          6.28.0-py312haa95532_0 --> 6.28.0-py310haa95532_0
#   ipython                            8.25.0-py312haa95532_0 --> 8.25.0-py310haa95532_0
#   ipywidgets                          8.1.2-py312haa95532_0 --> 8.1.2-py310haa95532_0
#   jedi                               0.19.1-py312haa95532_0 --> 0.19.1-py310haa95532_0
#   jinja2                              3.1.4-py312haa95532_0 --> 3.1.4-py310haa95532_0
#   jsonpatch                            1.33-py312haa95532_1 --> 1.33-py310haa95532_1
#   jsonschema                         4.19.2-py312haa95532_0 --> 4.19.2-py310haa95532_0
#   jsonschema-specif~               2023.7.1-py312haa95532_0 --> 2023.7.1-py310haa95532_0
#   jupyter                             1.0.0-py312haa95532_9 --> 1.0.0-py310haa95532_9
#   jupyter-lsp                         2.2.0-py312haa95532_0 --> 2.2.0-py310haa95532_0
#   jupyter_client                      8.6.0-py312haa95532_0 --> 8.6.0-py310haa95532_0
#   jupyter_console                     6.6.3-py312haa95532_1 --> 6.6.3-py310haa95532_0
#   jupyter_core                        5.7.2-py312haa95532_0 --> 5.7.2-py310haa95532_0
#   jupyter_events                     0.10.0-py312haa95532_0 --> 0.10.0-py310haa95532_0
#   jupyter_server                     2.14.1-py312haa95532_0 --> 2.14.1-py310haa95532_0
#   jupyter_server_te~                  0.4.4-py312haa95532_1 --> 0.4.4-py310haa95532_1
#   jupyterlab                         4.0.11-py312haa95532_0 --> 4.0.11-py310haa95532_0
#   jupyterlab_server                  2.25.1-py312haa95532_0 --> 2.25.1-py310haa95532_0
#   jupyterlab_widgets                 3.0.10-py312haa95532_0 --> 3.0.10-py310haa95532_0
#   libmambapy                          1.5.8-py312h77c03ed_2 --> 1.5.8-py310h77c03ed_2
#   markupsafe                          2.1.3-py312h2bbff1b_0 --> 2.1.3-py310h2bbff1b_0
#   matplotlib-inline                   0.1.6-py312haa95532_0 --> 0.1.6-py310haa95532_0
#   menuinst                            2.1.1-py312h5da7b33_0 --> 2.1.1-py310h5da7b33_0
#   mistune                             2.0.4-py312haa95532_0 --> 2.0.4-py310haa95532_0
#   nbclient                            0.8.0-py312haa95532_0 --> 0.8.0-py310haa95532_0
#   nbconvert                          7.10.0-py312haa95532_0 --> 7.10.0-py310haa95532_0
#   nbformat                            5.9.2-py312haa95532_0 --> 5.9.2-py310haa95532_0
#   nest-asyncio                        1.6.0-py312haa95532_0 --> 1.6.0-py310haa95532_0
#   notebook                            7.0.8-py312haa95532_2 --> 7.0.8-py310haa95532_2
#   notebook-shim                       0.2.3-py312haa95532_0 --> 0.2.3-py310haa95532_0
#   overrides                           7.4.0-py312haa95532_0 --> 7.4.0-py310haa95532_0
#   pip                                  24.0-py312haa95532_0 --> 24.0-py310haa95532_0
#   platformdirs                       3.10.0-py312haa95532_0 --> 3.10.0-py310haa95532_0
#   pluggy                              1.0.0-py312haa95532_1 --> 1.0.0-py310haa95532_1
#   ply                                  3.11-py312haa95532_1 --> 3.11-py310haa95532_0
#   prometheus_client                  0.14.1-py312haa95532_0 --> 0.14.1-py310haa95532_0
#   prompt-toolkit                     3.0.43-py312haa95532_0 --> 3.0.43-py310haa95532_0
#   psutil                              5.9.0-py312h2bbff1b_0 --> 5.9.0-py310h2bbff1b_0
#   pycosat                             0.6.6-py312h2bbff1b_1 --> 0.6.6-py310h2bbff1b_1
#   pygments                           2.15.1-py312haa95532_1 --> 2.15.1-py310haa95532_1
#   pyqt                              5.15.10-py312hd77b12b_0 --> 5.15.10-py310hd77b12b_0
#   pyqt5-sip                         12.13.0-py312h2bbff1b_0 --> 12.13.0-py310h2bbff1b_0
#   pysocks                             1.7.1-py312haa95532_0 --> 1.7.1-py310haa95532_0
#   python                                  3.12.4-h14ffc60_1 --> 3.10.14-he1021f5_1
#   python-dateutil                2.9.0post0-py312haa95532_2 --> 2.9.0post0-py310haa95532_2
#   python-fastjsonsc~                 2.16.2-py312haa95532_0 --> 2.16.2-py310haa95532_0
#   python-json-logger                  2.0.7-py312haa95532_0 --> 2.0.7-py310haa95532_0
#   pytz                               2024.1-py312haa95532_0 --> 2024.1-py310haa95532_0
#   pywin32                               305-py312h2bbff1b_0 --> 305-py310h2bbff1b_0
#   pywinpty                           2.0.10-py312h5da7b33_0 --> 2.0.10-py310h5da7b33_0
#   pyyaml                              6.0.1-py312h2bbff1b_0 --> 6.0.1-py310h2bbff1b_0
#   pyzmq                              25.1.2-py312hd77b12b_0 --> 25.1.2-py310hd77b12b_0
#   qtconsole                           5.5.1-py312haa95532_0 --> 5.5.1-py310haa95532_0
#   qtpy                                2.4.1-py312haa95532_0 --> 2.4.1-py310haa95532_0
#   referencing                        0.30.2-py312haa95532_0 --> 0.30.2-py310haa95532_0
#   rfc3339-validator                   0.1.4-py312haa95532_0 --> 0.1.4-py310haa95532_0
#   rfc3986-validator                   0.1.1-py312haa95532_0 --> 0.1.1-py310haa95532_0
#   rpds-py                            0.10.6-py312h062c2fa_0 --> 0.10.6-py310h062c2fa_0
#   ruamel.yaml                       0.17.21-py312h2bbff1b_0 --> 0.17.21-py310h2bbff1b_0
#   send2trash                          1.8.2-py312haa95532_0 --> 1.8.2-py310haa95532_0
#   setuptools                         69.5.1-py312haa95532_0 --> 69.5.1-py310haa95532_0
#   sip                                6.7.12-py312hd77b12b_0 --> 6.7.12-py310hd77b12b_0
#   sniffio                             1.3.0-py312haa95532_0 --> 1.3.0-py310haa95532_0
#   soupsieve                             2.5-py312haa95532_0 --> 2.5-py310haa95532_0
#   terminado                          0.17.1-py312haa95532_0 --> 0.17.1-py310haa95532_0
#   tinycss2                            1.2.1-py312haa95532_0 --> 1.2.1-py310haa95532_0
#   tornado                             6.4.1-py312h827c3e9_0 --> 6.4.1-py310h827c3e9_0
#   tqdm                               4.66.4-py312hfc267ef_0 --> 4.66.4-py310h9909e9c_0
#   traitlets                          5.14.3-py312haa95532_0 --> 5.14.3-py310haa95532_0
#   truststore                          0.8.0-py312haa95532_0 --> 0.8.0-py310haa95532_0
#   typing-extensions                  4.11.0-py312haa95532_0 --> 4.11.0-py310haa95532_0
#   typing_extensions                  4.11.0-py312haa95532_0 --> 4.11.0-py310haa95532_0
#   urllib3                             2.2.2-py312haa95532_0 --> 2.2.2-py310haa95532_0
#   webencodings                        0.5.1-py312haa95532_2 --> 0.5.1-py310haa95532_1
#   websocket-client                    1.8.0-py312haa95532_0 --> 1.8.0-py310haa95532_0
#   wheel                              0.43.0-py312haa95532_0 --> 0.43.0-py310haa95532_0
#   widgetsnbextension                 4.0.10-py312haa95532_0 --> 4.0.10-py310haa95532_0
#   win_inet_pton                       1.1.0-py312haa95532_0 --> 1.1.0-py310haa95532_0
#   zstandard                          0.22.0-py312h3469f8a_0 --> 0.22.0-py310h3469f8a_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/r/noarch/repodata.json.zst
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/r/win-64/repodata.json.zst
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/main/win-64/repodata.json.zst
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/main/noarch/repodata.json.zst
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/msys2/win-64/repodata.json.zst
#
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/msys2/noarch/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/main/noarch/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/msys2/noarch/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/r/win-64/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/msys2/win-64/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/r/noarch/repodata.json.zst
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /pkgs/main/win-64/repodata.json.zst
#
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - conda-forge::vapoursynth=69
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     ucrt-10.0.20348.0          |       haa95532_0         531 KB
#     vapoursynth-69             |  py310h73ae2b4_0         962 KB  conda-forge
#     vc-14.3                    |      h8a93ad2_20          17 KB  conda-forge
#     vc14_runtime-14.40.33810   |      ha82c5b3_20         734 KB  conda-forge
#     vs2015_runtime-14.40.33810 |      h3bf8584_20          17 KB  conda-forge
#     zimg-3.0.5                 |       h63175ca_0         221 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/win-64::python_abi-3.10-2_cp310
#   ucrt               pkgs/main/win-64::ucrt-10.0.20348.0-haa95532_0
#   vapoursynth        conda-forge/win-64::vapoursynth-69-py310h73ae2b4_0
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.40.33810-ha82c5b3_20
#   zimg               conda-forge/win-64::zimg-3.0.5-h63175ca_0
#
# The following packages will be UPDATED:
#
#   vc                          pkgs/main::vc-14.2-h2eaa2aa_1 --> conda-forge::vc-14.3-h8a93ad2_20
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.29.30133~ --> conda-forge::vs2015_runtime-14.40.33810-h3bf8584_20
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... VapourSynth plugin autoload directory is changed to D:\miniconda3\vs-plugins starting from v67. Please migrate your plugins to the new directory.
#
# done
# Channels:
#  - main
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - libarchive
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libarchive-3.6.2           |       hb62f4d4_3         1.8 MB
#     ------------------------------------------------------------
#                                            Total:         1.8 MB
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - defaults
#  - tongyuantongyu
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - tongyuantongyu::vapoursynth-bestsource=5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.9.1                  |       he0c23c2_0         1.9 MB  conda-forge
#     cairo-1.18.0               |       h1fef639_0         1.4 MB  conda-forge
#     dav1d-1.2.1                |       h2bbff1b_0         672 KB
#     ffmpeg-7.0.1               | gpl_h7cec250_100         9.5 MB  conda-forge
#     fmt-10.2.1                 |       h181d51b_0         181 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.2          |       hbde0cde_0         186 KB  conda-forge
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     freetype-2.12.1            |       ha860e81_0         490 KB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     harfbuzz-8.5.0             |       h81778c3_0         1.0 MB  conda-forge
#     icu-73.2                   |       h63175ca_0        12.8 MB  conda-forge
#     libarchive-3.7.4           |       haf234dc_0         935 KB  conda-forge
#     libglib-2.80.2             |       h0df6a38_0         3.6 MB  conda-forge
#     libiconv-1.17              |       hcfcfb64_2         621 KB  conda-forge
#     libintl-0.22.5             |       h5728263_2          94 KB  conda-forge
#     libmamba-1.5.8             |       h3f09ed1_0         3.4 MB  conda-forge
#     libmambapy-1.5.8           |  py310h04f2035_0         330 KB  conda-forge
#     libopus-1.3.1              |       h8ffe710_1         255 KB  conda-forge
#     libsolv-0.7.29             |       h0ea2cb4_0         419 KB  conda-forge
#     libxml2-2.13.1             |       h24da03e_2         2.9 MB
#     libzlib-1.2.13             |       h2466b09_6          55 KB  conda-forge
#     lzo-2.10                   |       he774522_2         142 KB
#     openh264-2.4.1             |       h63175ca_0         400 KB  conda-forge
#     openssl-3.3.1              |       h2466b09_2         8.0 MB  conda-forge
#     pcre2-10.43                |       h17e33f8_0         799 KB  conda-forge
#     pixman-0.43.4              |       h63175ca_0         451 KB  conda-forge
#     pybind11-abi-4             |       hd3eb1b0_1          14 KB
#     svt-av1-2.1.0              |       he0c23c2_0         1.9 MB  conda-forge
#     vapoursynth-bestsource-5   |       h8b6cc4e_0         136 KB  tongyuantongyu
#     x264-1!164.3095            |       h8ffe710_2        1017 KB  conda-forge
#     x265-3.5                   |       h2d74725_3         5.3 MB  conda-forge
#     xxhash-0.8.2               |       hcfcfb64_0         101 KB  conda-forge
#     zlib-1.2.13                |       h2466b09_6         105 KB  conda-forge
#     zstandard-0.19.0           |  py310h2bbff1b_0         340 KB
#     zstd-1.5.6                 |       h0ea2cb4_0         341 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        62.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/win-64::aom-3.9.1-he0c23c2_0
#   cairo              conda-forge/win-64::cairo-1.18.0-h1fef639_0
#   dav1d              pkgs/main/win-64::dav1d-1.2.1-h2bbff1b_0
#   ffmpeg             conda-forge/win-64::ffmpeg-7.0.1-gpl_h7cec250_100
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         conda-forge/win-64::fontconfig-2.14.2-hbde0cde_0
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           pkgs/main/win-64::freetype-2.12.1-ha860e81_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   harfbuzz           conda-forge/win-64::harfbuzz-8.5.0-h81778c3_0
#   libglib            conda-forge/win-64::libglib-2.80.2-h0df6a38_0
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_2
#   libopus            conda-forge/win-64::libopus-1.3.1-h8ffe710_1
#   libzlib            conda-forge/win-64::libzlib-1.2.13-h2466b09_6
#   lzo                pkgs/main/win-64::lzo-2.10-he774522_2
#   openh264           conda-forge/win-64::openh264-2.4.1-h63175ca_0
#   pixman             conda-forge/win-64::pixman-0.43.4-h63175ca_0
#   svt-av1            conda-forge/win-64::svt-av1-2.1.0-he0c23c2_0
#   vapoursynth-bests~ tongyuantongyu/win-64::vapoursynth-bestsource-5-h8b6cc4e_0
#   x264               conda-forge/win-64::x264-1!164.3095-h8ffe710_2
#   x265               conda-forge/win-64::x265-3.5-h2d74725_3
#   xxhash             conda-forge/win-64::xxhash-0.8.2-hcfcfb64_0
#
# The following packages will be UPDATED:
#
#   fmt                       pkgs/main::fmt-9.1.0-h6d14046_1 --> conda-forge::fmt-10.2.1-h181d51b_0
#   icu                        pkgs/main::icu-73.1-h6c2663c_0 --> conda-forge::icu-73.2-h63175ca_0
#   libarchive         pkgs/main::libarchive-3.6.2-hb62f4d4_3 --> conda-forge::libarchive-3.7.4-haf234dc_0
#   libiconv              pkgs/main::libiconv-1.16-h2bbff1b_3 --> conda-forge::libiconv-1.17-hcfcfb64_2
#   libsolv              pkgs/main::libsolv-0.7.24-h23ce68f_1 --> conda-forge::libsolv-0.7.29-h0ea2cb4_0
#   libxml2                                 2.10.4-h0ad7f3c_2 --> 2.13.1-h24da03e_2
#   openssl              pkgs/main::openssl-3.0.14-h827c3e9_0 --> conda-forge::openssl-3.3.1-h2466b09_2
#   pcre2                   pkgs/main::pcre2-10.42-h0ff8eda_1 --> conda-forge::pcre2-10.43-h17e33f8_0
#   zlib                    pkgs/main::zlib-1.2.13-h8cc25b3_1 --> conda-forge::zlib-1.2.13-h2466b09_6
#   zstd                     pkgs/main::zstd-1.5.5-hd43e919_2 --> conda-forge::zstd-1.5.6-h0ea2cb4_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   libmamba             pkgs/main::libmamba-1.5.8-h99b1521_2 --> conda-forge::libmamba-1.5.8-h3f09ed1_0
#   libmambapy         pkgs/main::libmambapy-1.5.8-py310h77c~ --> conda-forge::libmambapy-1.5.8-py310h04f2035_0
#
# The following packages will be DOWNGRADED:
#
#   pybind11-abi                                 5-hd3eb1b0_0 --> 4-hd3eb1b0_1
#   zstandard                          0.22.0-py310h3469f8a_0 --> 0.19.0-py310h2bbff1b_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')': /conda-forge/noarch/repodata.json
#
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')': /conda-forge/noarch/repodata.json
#
# Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')': /conda-forge/noarch/repodata.json
# ^C
# ^C
# Channels:
#  - defaults
#  - tongyuantongyu
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - tongyuantongyu::vapoursynth-fmtconv=30
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vapoursynth-fmtconv-30     |       h82bb817_0         2.2 MB  tongyuantongyu
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   vapoursynth-fmtco~ tongyuantongyu/win-64::vapoursynth-fmtconv-30-h82bb817_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - defaults
#  - tongyuantongyu
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - tongyuantongyu::vapoursynth-mvsfunc=10.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vapoursynth-mvsfunc-10.10  |             py_0          25 KB  tongyuantongyu
#     ------------------------------------------------------------
#                                            Total:          25 KB
#
# The following NEW packages will be INSTALLED:
#
#   vapoursynth-mvsfu~ tongyuantongyu/noarch::vapoursynth-mvsfunc-10.10-py_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - defaults
#  - tongyuantongyu
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\miniconda3
#
#   added / updated specs:
#     - tongyuantongyu::vapoursynth-vsutil=0.8.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vapoursynth-vsutil-0.8.0   |             py_0          14 KB  tongyuantongyu
#     ------------------------------------------------------------
#                                            Total:          14 KB
#
# The following NEW packages will be INSTALLED:
#
#   vapoursynth-vsutil tongyuantongyu/noarch::vapoursynth-vsutil-0.8.0-py_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting git+https://github.com/HomeOfVapourSynthEvolution/havsfunc.git
#   Cloning https://github.com/HomeOfVapourSynthEvolution/havsfunc.git to c:\users\haiqu\appdata\local\temp\pip-req-build-7k0d8h34
#   Resolved https://github.com/HomeOfVapourSynthEvolution/havsfunc.git to commit 8707846664a692108c579780e27061ca593559f8
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: vapoursynth>=66 in d:\miniconda3\lib\site-packages (from havsfunc==33) (69)
# Collecting vsdenoise (from havsfunc==33)
#   Downloading vsdenoise-2.4.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting vsexprtools (from havsfunc==33)
#   Downloading vsexprtools-1.4.6-py3-none-any.whl.metadata (841 bytes)
# Collecting vsmasktools (from havsfunc==33)
#   Downloading vsmasktools-1.1.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting vsrgtools (from havsfunc==33)
#   Downloading vsrgtools-1.5.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting vstools (from havsfunc==33)
#   Downloading vstools-2.3.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting vskernels>=2.4.1 (from vsdenoise->havsfunc==33)
#   Downloading vskernels-2.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting vsaa>=1.8.2 (from vsdenoise->havsfunc==33)
#   Downloading vsaa-1.8.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting vsscale>=1.9.1 (from vsdenoise->havsfunc==33)
#   Downloading vsscale-1.9.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting vspyplugin>=1.3.2 (from vsrgtools->havsfunc==33)
#   Downloading vspyplugin-1.3.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting rich>=12.6.0 (from vstools->havsfunc==33)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.6.0->vstools->havsfunc==33)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\miniconda3\lib\site-packages (from rich>=12.6.0->vstools->havsfunc==33) (2.15.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.6.0->vstools->havsfunc==33)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading vsdenoise-2.4.0-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/71.9 kB ? eta -:--:--
#    ---------------------- ----------------- 41.0/71.9 kB 487.6 kB/s eta 0:00:01
#    ---------------------------------------- 71.9/71.9 kB 656.3 kB/s eta 0:00:00
# Downloading vsexprtools-1.4.6-py3-none-any.whl (16 kB)
# Downloading vsmasktools-1.1.2-py3-none-any.whl (37 kB)
# Downloading vsrgtools-1.5.1-py3-none-any.whl (24 kB)
# Downloading vstools-2.3.0-py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.9 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/100.9 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 100.9/100.9 kB 1.4 MB/s eta 0:00:00
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Downloading vsaa-1.8.2-py3-none-any.whl (14 kB)
# Downloading vskernels-2.4.1-py3-none-any.whl (21 kB)
# Downloading vspyplugin-1.3.2-py3-none-any.whl (27 kB)
# Downloading vsscale-1.9.1-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.7 kB ? eta -:--:--
#    ------------ --------------------------- 92.2/301.7 kB 2.6 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/301.7 kB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/301.7 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 301.7/301.7 kB 2.1 MB/s eta 0:00:00
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: havsfunc
#   Building wheel for havsfunc (pyproject.toml): started
#   Building wheel for havsfunc (pyproject.toml): finished with status 'done'
#   Created wheel for havsfunc: filename=havsfunc-33-py3-none-any.whl size=51758 sha256=0cd7b52c68b3df04006c2e247bb3b18fa8fbbb07e8c591bb18c3bb1b6016accd
#   Stored in directory: C:\Users\haiqu\AppData\Local\Temp\pip-ephem-wheel-cache-it2jeikq\wheels\cb\c9\73\7470f98957ca8941836920806199a537076032042c2008731e
# Successfully built havsfunc
# Installing collected packages: mdurl, markdown-it-py, rich, vstools, vspyplugin, vskernels, vsexprtools, vsrgtools, vsmasktools, vsaa, vsscale, vsdenoise, havsfunc
# Successfully installed havsfunc-33 markdown-it-py-3.0.0 mdurl-0.1.2 rich-13.7.1 vsaa-1.8.2 vsdenoise-2.4.0 vsexprtools-1.4.6 vskernels-2.4.1 vsmasktools-1.1.2 vspyplugin-1.3.2 vsrgtools-1.5.1 vsscale-1.9.1 vstools-2.3.0
#   Running command git clone --filter=blob:none --quiet https://github.com/HomeOfVapourSynthEvolution/havsfunc.git 'C:\Users\haiqu\AppData\Local\Temp\pip-req-build-7k0d8h34'
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 540.4 kB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/15.8 MB 1.8 MB/s eta 0:00:09
#     --------------------------------------- 0.2/15.8 MB 2.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/15.8 MB 3.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/15.8 MB 4.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.8/15.8 MB 7.0 MB/s eta 0:00:03
#    ------- -------------------------------- 3.2/15.8 MB 10.6 MB/s eta 0:00:02
#    ------------- -------------------------- 5.3/15.8 MB 15.4 MB/s eta 0:00:01
#    ------------------- -------------------- 7.5/15.8 MB 19.3 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.8 MB 23.7 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.8 MB 23.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.8 MB 32.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.8 MB 32.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.8 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 34.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Collecting opencv-python==4.10.0.82
#   Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in d:\miniconda3\lib\site-packages (from opencv-python==4.10.0.82) (1.26.4)
# Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.82
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.4.0%2Bcu118-cp310-cp310-win_amd64.whl (2692.5 MB)
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 262.6 kB/s eta 2:50:55
#      ---------------------------------------- 0.0/2.7 GB 328.2 kB/s eta 2:16:44
#      ---------------------------------------- 0.0/2.7 GB 403.5 kB/s eta 1:51:12
#      ---------------------------------------- 0.0/2.7 GB 481.4 kB/s eta 1:33:14
#      ---------------------------------------- 0.0/2.7 GB 583.1 kB/s eta 1:16:58
#      ---------------------------------------- 0.0/2.7 GB 625.1 kB/s eta 1:11:47
#      ---------------------------------------- 0.0/2.7 GB 708.9 kB/s eta 1:03:18
#      ---------------------------------------- 0.0/2.7 GB 890.4 kB/s eta 0:50:24
#      ---------------------------------------- 0.0/2.7 GB 1.0 MB/s eta 0:44:41
#      ---------------------------------------- 0.0/2.7 GB 1.0 MB/s eta 0:43:06
#      ---------------------------------------- 0.0/2.7 GB 1.1 MB/s eta 0:41:45
#      ---------------------------------------- 0.0/2.7 GB 1.3 MB/s eta 0:34:40
#      ---------------------------------------- 0.0/2.7 GB 1.6 MB/s eta 0:27:54
#      ---------------------------------------- 0.0/2.7 GB 1.6 MB/s eta 0:27:45
#      ---------------------------------------- 0.0/2.7 GB 1.6 MB/s eta 0:27:23
#      ---------------------------------------- 0.0/2.7 GB 1.9 MB/s eta 0:23:08
#      ---------------------------------------- 0.0/2.7 GB 2.4 MB/s eta 0:18:40
#      ---------------------------------------- 0.0/2.7 GB 2.6 MB/s eta 0:17:29
#      ---------------------------------------- 0.0/2.7 GB 2.7 MB/s eta 0:16:33
#      ---------------------------------------- 0.0/2.7 GB 3.1 MB/s eta 0:14:19
#      ---------------------------------------- 0.0/2.7 GB 3.9 MB/s eta 0:11:29
#      ---------------------------------------- 0.0/2.7 GB 4.3 MB/s eta 0:10:29
#      ---------------------------------------- 0.0/2.7 GB 4.6 MB/s eta 0:09:45
#      ---------------------------------------- 0.0/2.7 GB 5.2 MB/s eta 0:08:38
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:14
#      ---------------------------------------- 0.0/2.7 GB 7.0 MB/s eta 0:06:23
#      ---------------------------------------- 0.0/2.7 GB 7.8 MB/s eta 0:05:46
#      ---------------------------------------- 0.0/2.7 GB 14.5 MB/s eta 0:03:05
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 34.4 MB/s eta 0:01:18
#      ---------------------------------------- 0.0/2.7 GB 43.5 MB/s eta 0:01:02
#      ---------------------------------------- 0.0/2.7 GB 46.7 MB/s eta 0:00:58
#      ---------------------------------------- 0.0/2.7 GB 54.4 MB/s eta 0:00:50
#      ---------------------------------------- 0.0/2.7 GB 50.4 MB/s eta 0:00:53
#      ---------------------------------------- 0.0/2.7 GB 50.4 MB/s eta 0:00:53
#      ---------------------------------------- 0.0/2.7 GB 59.5 MB/s eta 0:00:45
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 65.6 MB/s eta 0:00:41
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.0/2.7 GB 21.1 MB/s eta 0:02:07
#       --------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:07
#       --------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:07
#       --------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:07
#       --------------------------------------- 0.0/2.7 GB 11.7 MB/s eta 0:03:48
#       --------------------------------------- 0.0/2.7 GB 11.7 MB/s eta 0:03:48
#       --------------------------------------- 0.0/2.7 GB 11.7 MB/s eta 0:03:48
#       --------------------------------------- 0.0/2.7 GB 10.1 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.7 GB 10.1 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.7 GB 10.1 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.7 GB 9.1 MB/s eta 0:04:53
#       --------------------------------------- 0.0/2.7 GB 9.0 MB/s eta 0:04:56
#       --------------------------------------- 0.0/2.7 GB 9.0 MB/s eta 0:04:56
#       --------------------------------------- 0.0/2.7 GB 8.2 MB/s eta 0:05:25
#       --------------------------------------- 0.0/2.7 GB 8.1 MB/s eta 0:05:29
#       --------------------------------------- 0.0/2.7 GB 8.0 MB/s eta 0:05:33
#       --------------------------------------- 0.0/2.7 GB 8.0 MB/s eta 0:05:33
#       --------------------------------------- 0.0/2.7 GB 7.4 MB/s eta 0:05:57
#       --------------------------------------- 0.0/2.7 GB 9.6 MB/s eta 0:04:36
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 18.2 MB/s eta 0:02:26
#       --------------------------------------- 0.0/2.7 GB 19.3 MB/s eta 0:02:18
#       --------------------------------------- 0.1/2.7 GB 330.0 MB/s eta 0:00:08
#       --------------------------------------- 0.1/2.7 GB 217.7 MB/s eta 0:00:13
#       --------------------------------------- 0.1/2.7 GB 217.7 MB/s eta 0:00:13
#       --------------------------------------- 0.1/2.7 GB 217.7 MB/s eta 0:00:13
#       --------------------------------------- 0.1/2.7 GB 46.7 MB/s eta 0:00:57
#       --------------------------------------- 0.1/2.7 GB 40.9 MB/s eta 0:01:05
# ...
#      -------------------------------------- - 2.6/2.7 GB 65.6 MB/s eta 0:00:02
#      -------------------------------------- - 2.6/2.7 GB 59.5 MB/s eta 0:00:02
#      -------------------------------------- - 2.6/2.7 GB 59.5 MB/s eta 0:00:02
#      -------------------------------------- - 2.6/2.7 GB 59.5 MB/s eta 0:00:02
#      -------------------------------------- - 2.6/2.7 GB 59.8 MB/s eta 0:00:02
#      -------------------------------------- - 2.6/2.7 GB 65.6 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.7 GB 65.6 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 59.5 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.7 GB 65.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 59.5 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 59.5 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 65.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 72.6 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 GB 24.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 GB 2.2 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.19.0%2Bcu118-cp310-cp310-win_amd64.whl (5.0 MB)
#      ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#      ------------- -------------------------- 1.7/5.0 MB 53.2 MB/s eta 0:00:01
#      ---------------- ----------------------- 2.1/5.0 MB 26.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.8/5.0 MB 30.0 MB/s eta 0:00:01
#      ---------------------------------------  5.0/5.0 MB 32.1 MB/s eta 0:00:01
#      ---------------------------------------- 5.0/5.0 MB 29.2 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.4.0%2Bcu118-cp310-cp310-win_amd64.whl (4.0 MB)
#      ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#      ------------ --------------------------- 1.2/4.0 MB 25.9 MB/s eta 0:00:01
#      ------------------------------- -------- 3.1/4.0 MB 33.2 MB/s eta 0:00:01
#      ---------------------------------------  4.0/4.0 MB 31.9 MB/s eta 0:00:01
#      ---------------------------------------- 4.0/4.0 MB 28.4 MB/s eta 0:00:00
# Collecting filelock (from torch)
#   Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\miniconda3\lib\site-packages (from torch) (4.11.0)
# Collecting sympy (from torch)
#   Using cached https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch)
#   Using cached https://download.pytorch.org/whl/networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: jinja2 in d:\miniconda3\lib\site-packages (from torch) (3.1.4)
# Collecting fsspec (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2024.2.0-py3-none-any.whl (170 kB)
#      ---------------------------------------- 0.0/170.9 kB ? eta -:--:--
#      ---------------------------------------- 170.9/170.9 kB ? eta 0:00:00
# Requirement already satisfied: numpy in d:\miniconda3\lib\site-packages (from torchvision) (1.26.4)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading https://download.pytorch.org/whl/pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      --------------------- ------------------ 1.4/2.6 MB 45.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in d:\miniconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, networkx, fsspec, filelock, torch, torchvision, torchaudio
# Successfully installed filelock-3.13.1 fsspec-2024.2.0 mpmath-1.3.0 networkx-3.2.1 pillow-10.2.0 sympy-1.12 torch-2.4.0+cu118 torchaudio-2.4.0+cu118 torchvision-0.19.0+cu118
# Collecting vsrealesrgan
#   Using cached vsrealesrgan-5.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in d:\miniconda3\lib\site-packages (from vsrealesrgan) (1.26.4)
# Requirement already satisfied: requests in d:\miniconda3\lib\site-packages (from vsrealesrgan) (2.32.3)
# Requirement already satisfied: torch>=2.4.0.dev in d:\miniconda3\lib\site-packages (from vsrealesrgan) (2.4.0+cu118)
# Requirement already satisfied: tqdm in d:\miniconda3\lib\site-packages (from vsrealesrgan) (4.66.4)
# Requirement already satisfied: vapoursynth>=66 in d:\miniconda3\lib\site-packages (from vsrealesrgan) (69)
# Requirement already satisfied: filelock in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (4.11.0)
# Requirement already satisfied: sympy in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (1.12)
# Requirement already satisfied: networkx in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (3.2.1)
# Requirement already satisfied: jinja2 in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (3.1.4)
# Requirement already satisfied: fsspec in d:\miniconda3\lib\site-packages (from torch>=2.4.0.dev->vsrealesrgan) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\miniconda3\lib\site-packages (from requests->vsrealesrgan) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\miniconda3\lib\site-packages (from requests->vsrealesrgan) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\miniconda3\lib\site-packages (from requests->vsrealesrgan) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\miniconda3\lib\site-packages (from requests->vsrealesrgan) (2024.7.4)
# Requirement already satisfied: colorama in d:\miniconda3\lib\site-packages (from tqdm->vsrealesrgan) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\miniconda3\lib\site-packages (from jinja2->torch>=2.4.0.dev->vsrealesrgan) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in d:\miniconda3\lib\site-packages (from sympy->torch>=2.4.0.dev->vsrealesrgan) (1.3.0)
# Using cached vsrealesrgan-5.0.0-py3-none-any.whl (14 kB)
# Installing collected packages: vsrealesrgan
# Successfully installed vsrealesrgan-5.0.0
# Traceback (most recent call last):
#   File "D:\miniconda3\lib\runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "D:\miniconda3\lib\runpy.py", line 146, in _get_module_details
#     return _get_module_details(pkg_main_name, error)
#   File "D:\miniconda3\lib\runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "D:\miniconda3\lib\site-packages\vsrealesrgan\__init__.py", line 11, in <module>
#     import torch
#   File "D:\miniconda3\lib\site-packages\torch\__init__.py", line 148, in <module>
#     raise err
# OSError: [WinError 126] The specified module could not be found. Error loading "D:\miniconda3\lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.
